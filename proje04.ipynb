# %% [markdown]
# <a href="https://colab.research.google.com/github/ilayda-gunaydin/hu-bby162-2022/blob/main/proje04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Kütüphane Kataloglama

dosya = "/content/drive/MyDrive/Colab Notebooks/veritabani.txt"
print("Kütüphane Kataloglama Sistemine Hoş geldiniz\n")

def kitapListele():
  f = open(dosya, 'r')
  for line in f.readlines():
    print(line)
  f.close()
  menu()

def kitapKaydet():
  kitapAdi = input("Kitabın adını giriniz: ")
  kitapYazari = input("Kitabın yazarını giriniz: ")
  kitapYayinevi = input("Kitabın yayınevi bilgisini giriniz: ")
  kitapBasimTarihi = input("Kitabın basım tarihini giriniz: ")
  f = open(dosya, 'a' )
  f.write(kitapAdi + " | " + kitapYazari + " | " + kitapYayinevi + " | " + kitapBasimTarihi + " | " +'\n')
  print("Kitap kaydı başarıyla tamamlandı!")
  f.close()
  menu()

def kitapAra():
  kayitAra = input("Arama yapmak istediğiniz kitabın adını giriniz: ")
  kayit = open(dosya, "r")

  arananKayit = kayit.read().find(kayitAra)
  if arananKayit:
    print("Aradığınız kitap kataloğumuzda mevcuttur.")
    menu()
  else:
    print("Aradığınız kitap kataloğumuzda mevcut değildir.")
    menu()

def cikis():
  print("\t\t\nKataloğumuzdan çıkış yapmak istiyor musunuz?\n \t1) Evet\n  \t2) Hayır\n\t\t")
  cikisIslem = input("İşlem seçiniz: ")
  if cikisIslem == "2":
    print("Menüye yönlendirildiniz. Lütfen seçiminizi giriniz. ")
    menu()
  elif cikisIslem == "1":
   print("Çıkış işleminiz gerçekleşti.")
  else:
    print("Yanlış bir işlem yaptınız. Sadece 1 ve 2 seçebilirsiniz. ")
    cikis()

def menu():
  print("\t\t\nYapmak istediğiniz işlemi seçiniz:\n  \t1) Kitap Listele\n  \t2) Kitap Kaydet\n  \t3) Kitap Ara\n  \t4) Çıkış Yap\n\t\t")
  islem = input("İşlem seçiniz: ")
  if islem == "1":
    kitapListele()
  elif islem == "2":
    kitapKaydet()
  elif islem== "3":
    kitapAra()
  elif islem == "4":
    cikis()
  else:
    print("Yanlış giriş yaptınız! Menüye yönlendiriliyorsunuz.")
    menu()

menu()
# Out:
# Kütüphane Kataloglama Sistemine Hoş geldiniz
#
#
# Yapmak istediğiniz işlemi seçiniz:
#   	1) Kitap Listele
#   	2) Kitap Kaydet
#   	3) Kitap Ara
#   	4) Çıkış Yap
#
# İşlem seçiniz: 1
# gece yarısı kütüphanesi | matt haig | domingo yayınları | 2021 |
#
# şeker portakalı | jose mauro de vasconselos | can yayınları | 2000 |
#
# simyacı | paulo coelho | can yayınları | 2010 |
#
# beyaz zambaklar ülkesinde | grigory petrov | indigo yayınları | 2018 |
#
# ben kirke | madeline miller | ithaki yayınları | 2019 |
#
# kayıp tanrılar ülkesi | ahmet ümit | yapı kredi yayınları | 2021 |
#
# ay ışığı sokağı | stefan zweig | türkiye iş bankası kültür yayınları | 2017 |
#
# uçurtma avcısı | khaled hosseini | everest yayınları | 2004 |
#
# siddhartha | hermann hesse | can yayınları | 2002 |
#
# tehlikeli oyunlar | oğuz atay | iletişim yayınları | 2000 |
#
# Yapmak istediğiniz işlemi seçiniz:
#   	1) Kitap Listele
#   	2) Kitap Kaydet
#   	3) Kitap Ara
#   	4) Çıkış Yap
#
# İşlem seçiniz: 2
# ...
